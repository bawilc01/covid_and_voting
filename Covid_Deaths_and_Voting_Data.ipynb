# %%
import pandas as pd
import urllib3
from urllib3 import request
import json
import datetime
import dateutil.relativedelta
import certifi


# handle certificate verification and SSL warnings
# https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl
http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',
    ca_certs=certifi.where())

'''Historic US Covid Data'''
r = http.request('GET', "https://api.covidtracking.com/v1/us/daily.json")

# 200 status means response was successful
r.status
# Out:
# 200

# %%
# decode json data into a dict object
# each piece of data in between } is one item in the list
data = json.loads(r.data.decode('utf-8'))
data

# in this dataset, there is no extra field for extraction, so normalize only needs "data"
df = pd.json_normalize(data)
df.head(10)
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20201122      56  12077354  144261686  17578.0                83782.0
# 1  20201121      56  11927256  143010617  17683.0                83227.0
# 2  20201120      56  11748947  141584067  16221.0                82150.0
# 3  20201119      56  11556142  140194185  14596.0                80585.0
# 4  20201118      56  11373310  138907553  12971.0                79410.0
# 5  20201117      56  11209335  137833090   9281.0                76958.0
# 6  20201116      56  11052613  136740628  13639.0                73268.0
# 7  20201115      56  10903745  135637101  13654.0                70113.0
# 8  20201114      56  10759311  134474547  13657.0                69498.0
# 9  20201113      56  10595771  133299835  12010.0                68496.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                543179.0         16206.0          28828.0
# 1                540906.0         16054.0          28693.0
# 2                537665.0         15929.0          28472.0
# 3                533844.0         15572.0          28216.0
# 4                529168.0         15350.0          27989.0
# 5                524678.0         14851.0          27681.0
# 6                520763.0         14317.0          27437.0
# 7                517615.0         13693.0          27269.0
# 8                515739.0         13337.0          27172.0
# 9                512274.0         13132.0          26997.0
#
#    onVentilatorCurrently  ...  totalTestResults          lastModified total  \
# 0                 5233.0  ...         179340847  2020-11-22T24:00:00Z     0
# 1                 5103.0  ...         177614398  2020-11-21T24:00:00Z     0
# 2                 5055.0  ...         175636998  2020-11-20T24:00:00Z     0
# 3                 4859.0  ...         173719522  2020-11-19T24:00:00Z     0
# 4                 4701.0  ...         171901997  2020-11-18T24:00:00Z     0
# 5                 4379.0  ...         170367424  2020-11-17T24:00:00Z     0
# 6                 4166.0  ...         168863890  2020-11-16T24:00:00Z     0
# 7                 3939.0  ...         167385710  2020-11-15T24:00:00Z     0
# 8                 3945.0  ...         165770726  2020-11-14T24:00:00Z     0
# 9                 3769.0  ...         164109437  2020-11-13T24:00:00Z     0
#
#    posNeg  deathIncrease  hospitalizedIncrease negativeIncrease  \
# 0       0            889                  2273          1251069
# 1       0           1506                  3241          1426550
# 2       0           1862                  3821          1389882
# 3       0           1971                  4676          1286632
# 4       0           1869                  4490          1074463
# 5       0           1555                  3915          1092462
# 6       0            637                  3148          1103527
# 7       0            677                  1876          1162554
# 8       0           1312                  3465          1174712
# 9       0           1275                  3693          1237330
#
#    positiveIncrease  totalTestResultsIncrease  \
# 0            150098                   1726449
# 1            178309                   1977400
# 2            192805                   1917476
# 3            182832                   1817525
# 4            163975                   1534573
# 5            156722                   1503534
# 6            148868                   1478180
# 7            144434                   1614984
# 8            163540                   1661289
# 9            172106                   1695579
#
#                                        hash
# 0  b80bc58dae22f2d0a470c2210c1219edd939e216
# 1  cf675a8bdc6204a364c0fe4779d944ae529c617d
# 2  8c8f17669a85cd0219f9530754214d40bf7ae6fc
# 3  d24dcd1fddf40d007e34366d8abae03f2232bf92
# 4  5dc1b316e5e7b6ecaff11b00041cf335793ee775
# 5  4b92f29fcf980dedba895d88f44d26ea816be797
# 6  b556091da971f8138e0eaf7ac994d0338e4d742c
# 7  2c761b5acd54d250ddcaa0dbcee9b8365d0cb3c6
# 8  26be9bfa6f792c85562ca2d6ad1670294dd1b66d
# 9  1452dca2200c81bc0b33f059afb5eb1c745d13c4
#
# [10 rows x 25 columns]

# %%
# handle certificate verification and SSL warnings
# https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl
http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',
    ca_certs=certifi.where())

'''2020 Voting Info'''
r = http.request('GET', "https://api.open.fec.gov/v1/legal/search/?api_key=qc70YhrKttABiw2FYroE68OjmkYPlCfvve0ROWz9")

# 200 status means response was successful
r.status
# Out:
# 200

# %%
import pandas as pd

df = pd.read_csv (r'File name.csv')
print (df)
# Out:
#      no chapter                                               name title  \
# 0  9001      95                                        Short title    26
# 1  9002      95                                        Definitions    26
# 2  9003      95             Condition for eligibility for payments    26
# 3  9004      95     Entitlement of eligible candidates to payments    26
# 4  9005      95                        Certification by Commission    26
# 5  9006      95                    Payments to eligible candidates    26
# 6  9007      95                Examinations and audits; repayments    26
# 7  9008      95   Payments for presidential nominating conventions    26
# 8  9009      95                   Reports to Congress; regulations    26
# 9  9010      95  Participation by Commission in judicial procee...    26
#
#               doc_id                                          url highlights
# 0  /us/usc/t26/s9001  https://www.govinfo.gov/link/uscode/26/9001         []
# 1  /us/usc/t26/s9002  https://www.govinfo.gov/link/uscode/26/9002         []
# 2  /us/usc/t26/s9003  https://www.govinfo.gov/link/uscode/26/9003         []
# 3  /us/usc/t26/s9004  https://www.govinfo.gov/link/uscode/26/9004         []
# 4  /us/usc/t26/s9005  https://www.govinfo.gov/link/uscode/26/9005         []
# 5  /us/usc/t26/s9006  https://www.govinfo.gov/link/uscode/26/9006         []
# 6  /us/usc/t26/s9007  https://www.govinfo.gov/link/uscode/26/9007         []
# 7  /us/usc/t26/s9008  https://www.govinfo.gov/link/uscode/26/9008         []
# 8  /us/usc/t26/s9009  https://www.govinfo.gov/link/uscode/26/9009         []
# 9  /us/usc/t26/s9010  https://www.govinfo.gov/link/uscode/26/9010         []
