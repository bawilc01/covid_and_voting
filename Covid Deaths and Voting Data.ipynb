# %%
import pandas as pd
import urllib3
from urllib3 import request
import json
import datetime
import dateutil.relativedelta
import certifi


# handle certificate verification and SSL warnings
# https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl
http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',
    ca_certs=certifi.where())

'''Historic US Covid Data'''
r = http.request('GET', "https://api.covidtracking.com/v1/us/daily.json")

# 200 status means response was successful
r.status
# Out:
# 200

# %%
# decode json data into a dict object
# each piece of data in between } is one item in the list
data = json.loads(r.data.decode('utf-8'))
data
# Out:
# [{'date': 20201119,
#   'states': 56,
#   'positive': 11556142,
#   'negative': 140193927,
#   'pending': 14604,
#   'hospitalizedCurrently': 80698,
#   'hospitalizedCumulative': 533844,
#   'inIcuCurrently': 15573,
#   'inIcuCumulative': 28216,
#   'onVentilatorCurrently': 4859,
#   'onVentilatorCumulative': 3052,
#   'recovered': 4410709,
#   'dateChecked': '2020-11-19T24:00:00Z',
#   'death': 243675,
#   'hospitalized': 533844,
#   'totalTestResults': 173719264,
#   'lastModified': '2020-11-19T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1971,
#   'hospitalizedIncrease': 4676,
#   'negativeIncrease': 1286374,
#   'positiveIncrease': 182832,
#   'totalTestResultsIncrease': 1817267,
#   'hash': 'b7e10259ef39f2f226ef3613353a97ba985d3df8'},
#  {'date': 20201118,
#   'states': 56,
#   'positive': 11373310,
#   'negative': 138907553,
#   'pending': 12971,
#   'hospitalizedCurrently': 79410,
#   'hospitalizedCumulative': 529168,
#   'inIcuCurrently': 15350,
#   'inIcuCumulative': 27989,
#   'onVentilatorCurrently': 4701,
#   'onVentilatorCumulative': 3024,
#   'recovered': 4348089,
#   'dateChecked': '2020-11-18T24:00:00Z',
#   'death': 241704,
#   'hospitalized': 529168,
#   'totalTestResults': 171901997,
#   'lastModified': '2020-11-18T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1869,
#   'hospitalizedIncrease': 4490,
#   'negativeIncrease': 1074463,
#   'positiveIncrease': 163975,
#   'totalTestResultsIncrease': 1534573,
#   'hash': '5dc1b316e5e7b6ecaff11b00041cf335793ee775'},
#  {'date': 20201117,
#   'states': 56,
#   'positive': 11209335,
#   'negative': 137833090,
#   'pending': 9281,
#   'hospitalizedCurrently': 76958,
#   'hospitalizedCumulative': 524678,
#   'inIcuCurrently': 14851,
#   'inIcuCumulative': 27681,
#   'onVentilatorCurrently': 4379,
#   'onVentilatorCumulative': 3004,
#   'recovered': 4292094,
#   'dateChecked': '2020-11-17T24:00:00Z',
#   'death': 239835,
#   'hospitalized': 524678,
#   'totalTestResults': 170367424,
#   'lastModified': '2020-11-17T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1555,
#   'hospitalizedIncrease': 3915,
#   'negativeIncrease': 1092462,
#   'positiveIncrease': 156722,
#   'totalTestResultsIncrease': 1503534,
#   'hash': '4b92f29fcf980dedba895d88f44d26ea816be797'},
#  {'date': 20201116,
#   'states': 56,
#   'positive': 11052613,
#   'negative': 136740628,
#   'pending': 13639,
#   'hospitalizedCurrently': 73268,
#   'hospitalizedCumulative': 520763,
#   'inIcuCurrently': 14317,
#   'inIcuCumulative': 27437,
#   'onVentilatorCurrently': 4166,
#   'onVentilatorCumulative': 2988,
#   'recovered': 4242683,
#   'dateChecked': '2020-11-16T24:00:00Z',
#   'death': 238280,
#   'hospitalized': 520763,
#   'totalTestResults': 168863890,
#   'lastModified': '2020-11-16T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 637,
#   'hospitalizedIncrease': 3148,
#   'negativeIncrease': 1103527,
#   'positiveIncrease': 148868,
#   'totalTestResultsIncrease': 1478180,
#   'hash': 'b556091da971f8138e0eaf7ac994d0338e4d742c'},
#  {'date': 20201115,
#   'states': 56,
#   'positive': 10903745,
#   'negative': 135637101,
#   'pending': 13654,
#   'hospitalizedCurrently': 70113,
#   'hospitalizedCumulative': 517615,
#   'inIcuCurrently': 13693,
#   'inIcuCumulative': 27269,
#   'onVentilatorCurrently': 3939,
#   'onVentilatorCumulative': 2975,
#   'recovered': 4183378,
#   'dateChecked': '2020-11-15T24:00:00Z',
#   'death': 237643,
#   'hospitalized': 517615,
#   'totalTestResults': 167385710,
#   'lastModified': '2020-11-15T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 677,
#   'hospitalizedIncrease': 1876,
#   'negativeIncrease': 1162554,
#   'positiveIncrease': 144434,
#   'totalTestResultsIncrease': 1614984,
#   'hash': '2c761b5acd54d250ddcaa0dbcee9b8365d0cb3c6'},
#  {'date': 20201114,
#   'states': 56,
#   'positive': 10759311,
#   'negative': 134474547,
#   'pending': 13657,
#   'hospitalizedCurrently': 69498,
#   'hospitalizedCumulative': 515739,
#   'inIcuCurrently': 13337,
#   'inIcuCumulative': 27172,
#   'onVentilatorCurrently': 3945,
#   'onVentilatorCumulative': 2972,
#   'recovered': 4146419,
#   'dateChecked': '2020-11-14T24:00:00Z',
#   'death': 236966,
#   'hospitalized': 515739,
#   'totalTestResults': 165770726,
#   'lastModified': '2020-11-14T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1312,
#   'hospitalizedIncrease': 3465,
#   'negativeIncrease': 1174712,
#   'positiveIncrease': 163540,
#   'totalTestResultsIncrease': 1661289,
#   'hash': '26be9bfa6f792c85562ca2d6ad1670294dd1b66d'},
#  {'date': 20201113,
#   'states': 56,
#   'positive': 10595771,
#   'negative': 133299835,
#   'pending': 12010,
#   'hospitalizedCurrently': 68496,
#   'hospitalizedCumulative': 512274,
#   'inIcuCurrently': 13132,
#   'inIcuCumulative': 26997,
#   'onVentilatorCurrently': 3769,
#   'onVentilatorCumulative': 2967,
#   'recovered': 4093148,
#   'dateChecked': '2020-11-13T24:00:00Z',
#   'death': 235654,
#   'hospitalized': 512274,
#   'totalTestResults': 164109437,
#   'lastModified': '2020-11-13T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1275,
#   'hospitalizedIncrease': 3693,
#   'negativeIncrease': 1237330,
#   'positiveIncrease': 172106,
#   'totalTestResultsIncrease': 1695579,
#   'hash': '1452dca2200c81bc0b33f059afb5eb1c745d13c4'},
#  {'date': 20201112,
#   'states': 56,
#   'positive': 10423665,
#   'negative': 132062505,
#   'pending': 11385,
#   'hospitalizedCurrently': 67100,
#   'hospitalizedCumulative': 508581,
#   'inIcuCurrently': 12796,
#   'inIcuCumulative': 26803,
#   'onVentilatorCurrently': 3622,
#   'onVentilatorCumulative': 2954,
#   'recovered': 4049143,
#   'dateChecked': '2020-11-12T24:00:00Z',
#   'death': 234379,
#   'hospitalized': 508581,
#   'totalTestResults': 162413858,
#   'lastModified': '2020-11-12T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1141,
#   'hospitalizedIncrease': 3672,
#   'negativeIncrease': 970737,
#   'positiveIncrease': 152003,
#   'totalTestResultsIncrease': 1472332,
#   'hash': '9d498d32b0b7543dad0cde869fbed48f2c9898fa'},
#  {'date': 20201111,
#   'states': 56,
#   'positive': 10271662,
#   'negative': 131091768,
#   'pending': 11287,
#   'hospitalizedCurrently': 65463,
#   'hospitalizedCumulative': 504909,
#   'inIcuCurrently': 12518,
#   'inIcuCumulative': 26584,
#   'onVentilatorCurrently': 3367,
#   'onVentilatorCumulative': 2947,
#   'recovered': 3995023,
#   'dateChecked': '2020-11-11T24:00:00Z',
#   'death': 233238,
#   'hospitalized': 504909,
#   'totalTestResults': 160941526,
#   'lastModified': '2020-11-11T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1543,
#   'hospitalizedIncrease': 3423,
#   'negativeIncrease': 1019589,
#   'positiveIncrease': 144801,
#   'totalTestResultsIncrease': 1412859,
#   'hash': '7e61eb917900da850f3a5c7d0b1a834910deddf4'},
#  {'date': 20201110,
#   'states': 56,
#   'positive': 10126861,
#   'negative': 130072179,
#   'pending': 8579,
#   'hospitalizedCurrently': 62059,
#   'hospitalizedCumulative': 501486,
#   'inIcuCurrently': 11961,
#   'inIcuCumulative': 26335,
#   'onVentilatorCurrently': 3201,
#   'onVentilatorCumulative': 2922,
#   'recovered': 3959700,
#   'dateChecked': '2020-11-10T24:00:00Z',
#   'death': 231695,
#   'hospitalized': 501486,
#   'totalTestResults': 159528667,
#   'lastModified': '2020-11-10T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1360,
#   'hospitalizedIncrease': 4111,
#   'negativeIncrease': 941962,
#   'positiveIncrease': 131182,
#   'totalTestResultsIncrease': 1246063,
#   'hash': '761038ed5dc76a819989af6b8e06812f700a1d01'},
#  {'date': 20201109,
#   'states': 56,
#   'positive': 9995679,
#   'negative': 129130217,
#   'pending': 23458,
#   'hospitalizedCurrently': 59301,
#   'hospitalizedCumulative': 497375,
#   'inIcuCurrently': 11533,
#   'inIcuCumulative': 26087,
#   'onVentilatorCurrently': 3110,
#   'onVentilatorCumulative': 2907,
#   'recovered': 3926618,
#   'dateChecked': '2020-11-09T24:00:00Z',
#   'death': 230335,
#   'hospitalized': 497375,
#   'totalTestResults': 158282604,
#   'lastModified': '2020-11-09T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 589,
#   'hospitalizedIncrease': 2370,
#   'negativeIncrease': 1222518,
#   'positiveIncrease': 119432,
#   'totalTestResultsIncrease': 1512607,
#   'hash': '5e2a63b50dad6d6955ac40fa97e5d9b1fe4ebc65'},
#  {'date': 20201108,
#   'states': 56,
#   'positive': 9876247,
#   'negative': 127907699,
#   'pending': 23353,
#   'hospitalizedCurrently': 56842,
#   'hospitalizedCumulative': 495005,
#   'inIcuCurrently': 11120,
#   'inIcuCumulative': 25819,
#   'onVentilatorCurrently': 2977,
#   'onVentilatorCumulative': 2900,
#   'recovered': 3879255,
#   'dateChecked': '2020-11-08T24:00:00Z',
#   'death': 229746,
#   'hospitalized': 495005,
#   'totalTestResults': 156769997,
#   'lastModified': '2020-11-08T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 485,
#   'hospitalizedIncrease': 1506,
#   'negativeIncrease': 921916,
#   'positiveIncrease': 110281,
#   'totalTestResultsIncrease': 1251959,
#   'hash': '31f851f36f295a039db76e552dc92fd1bb074a71'},
#  {'date': 20201107,
#   'states': 56,
#   'positive': 9765966,
#   'negative': 126985783,
#   'pending': 23295,
#   'hospitalizedCurrently': 55925,
#   'hospitalizedCumulative': 493499,
#   'inIcuCurrently': 11082,
#   'inIcuCumulative': 25721,
#   'onVentilatorCurrently': 2947,
#   'onVentilatorCumulative': 2898,
#   'recovered': 3849345,
#   'dateChecked': '2020-11-07T24:00:00Z',
#   'death': 229261,
#   'hospitalized': 493499,
#   'totalTestResults': 155518038,
#   'lastModified': '2020-11-07T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1104,
#   'hospitalizedIncrease': 2291,
#   'negativeIncrease': 984198,
#   'positiveIncrease': 129215,
#   'totalTestResultsIncrease': 1412176,
#   'hash': '737bb8101d5579496862bc96ee8f2f3970fdb15e'},
#  {'date': 20201106,
#   'states': 56,
#   'positive': 9636751,
#   'negative': 126001585,
#   'pending': 11804,
#   'hospitalizedCurrently': 54851,
#   'hospitalizedCumulative': 491208,
#   'inIcuCurrently': 11085,
#   'inIcuCumulative': 25498,
#   'onVentilatorCurrently': 2850,
#   'onVentilatorCumulative': 2885,
#   'recovered': 3808730,
#   'dateChecked': '2020-11-06T24:00:00Z',
#   'death': 228157,
#   'hospitalized': 491208,
#   'totalTestResults': 154105862,
#   'lastModified': '2020-11-06T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1168,
#   'hospitalizedIncrease': 3142,
#   'negativeIncrease': 1140845,
#   'positiveIncrease': 125753,
#   'totalTestResultsIncrease': 1561333,
#   'hash': '7ee8d2561320544515105b8979549f0c6d66f468'},
#  {'date': 20201105,
#   'states': 56,
#   'positive': 9510998,
#   'negative': 124860740,
#   'pending': 11233,
#   'hospitalizedCurrently': 53375,
#   'hospitalizedCumulative': 488066,
#   'inIcuCurrently': 10918,
#   'inIcuCumulative': 25276,
#   'onVentilatorCurrently': 2877,
#   'onVentilatorCumulative': 2872,
#   'recovered': 3779523,
#   'dateChecked': '2020-11-05T24:00:00Z',
#   'death': 226989,
#   'hospitalized': 488066,
#   'totalTestResults': 152544529,
#   'lastModified': '2020-11-05T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1131,
#   'hospitalizedIncrease': 3413,
#   'negativeIncrease': 1177362,
#   'positiveIncrease': 116441,
#   'totalTestResultsIncrease': 1564524,
#   'hash': '61493e48061c1866aefba044cda079bf95787d5a'},
#  {'date': 20201104,
#   'states': 56,
#   'positive': 9394557,
#   'negative': 123683378,
#   'pending': 10117,
#   'hospitalizedCurrently': 52086,
#   'hospitalizedCumulative': 484653,
#   'inIcuCurrently': 10761,
#   'inIcuCumulative': 25041,
#   'onVentilatorCurrently': 2832,
#   'onVentilatorCumulative': 2853,
#   'recovered': 3741442,
#   'dateChecked': '2020-11-04T24:00:00Z',
#   'death': 225858,
#   'hospitalized': 484653,
#   'totalTestResults': 150980005,
#   'lastModified': '2020-11-04T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1126,
#   'hospitalizedIncrease': 3137,
#   'negativeIncrease': 869804,
#   'positiveIncrease': 103304,
#   'totalTestResultsIncrease': 1217991,
#   'hash': '6484efa20b26446aa68fb165aa3846a6a7023ae7'},
#  {'date': 20201103,
#   'states': 56,
#   'positive': 9291253,
#   'negative': 122813574,
#   'pending': 8003,
#   'hospitalizedCurrently': 50426,
#   'hospitalizedCumulative': 481516,
#   'inIcuCurrently': 10406,
#   'inIcuCumulative': 24796,
#   'onVentilatorCurrently': 2733,
#   'onVentilatorCumulative': 2833,
#   'recovered': 3702925,
#   'dateChecked': '2020-11-03T24:00:00Z',
#   'death': 224732,
#   'hospitalized': 481516,
#   'totalTestResults': 149762014,
#   'lastModified': '2020-11-03T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1515,
#   'hospitalizedIncrease': 3227,
#   'negativeIncrease': 839539,
#   'positiveIncrease': 86662,
#   'totalTestResultsIncrease': 1123667,
#   'hash': '2e96f144b730182e35e5bb1789f65a87ffffa2a8'},
#  {'date': 20201102,
#   'states': 56,
#   'positive': 9204591,
#   'negative': 121974035,
#   'pending': 10647,
#   'hospitalizedCurrently': 48557,
#   'hospitalizedCumulative': 478289,
#   'inIcuCurrently': 9858,
#   'inIcuCumulative': 24560,
#   'onVentilatorCurrently': 2637,
#   'onVentilatorCumulative': 2809,
#   'recovered': 3672742,
#   'dateChecked': '2020-11-02T24:00:00Z',
#   'death': 223217,
#   'hospitalized': 478289,
#   'totalTestResults': 148638347,
#   'lastModified': '2020-11-02T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 499,
#   'hospitalizedIncrease': 1518,
#   'negativeIncrease': 1070744,
#   'positiveIncrease': 82047,
#   'totalTestResultsIncrease': 1322758,
#   'hash': '42d60e41038ab108d27b862fdd5a7a7338baf632'},
#  {'date': 20201101,
#   'states': 56,
#   'positive': 9122544,
#   'negative': 120903291,
#   'pending': 10617,
#   'hospitalizedCurrently': 47531,
#   'hospitalizedCumulative': 476771,
#   'inIcuCurrently': 9553,
#   'inIcuCumulative': 24457,
#   'onVentilatorCurrently': 2553,
#   'onVentilatorCumulative': 2797,
#   'recovered': 3631622,
#   'dateChecked': '2020-11-01T24:00:00Z',
#   'death': 222718,
#   'hospitalized': 476771,
#   'totalTestResults': 147315589,
#   'lastModified': '2020-11-01T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 388,
#   'hospitalizedIncrease': 1145,
#   'negativeIncrease': 814180,
#   'positiveIncrease': 73849,
#   'totalTestResultsIncrease': 1127464,
#   'hash': 'e2933608de7ab2cc418d808cb4cdcf4a54d091ae'},
#  {'date': 20201031,
#   'states': 56,
#   'positive': 9048695,
#   'negative': 120089111,
#   'pending': 10635,
#   'hospitalizedCurrently': 47402,
#   'hospitalizedCumulative': 475626,
#   'inIcuCurrently': 9499,
#   'inIcuCumulative': 24375,
#   'onVentilatorCurrently': 2502,
#   'onVentilatorCumulative': 2786,
#   'recovered': 3610296,
#   'dateChecked': '2020-10-31T24:00:00Z',
#   'death': 222330,
#   'hospitalized': 475626,
#   'totalTestResults': 146188125,
#   'lastModified': '2020-10-31T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 951,
#   'hospitalizedIncrease': 2029,
#   'negativeIncrease': 1043992,
#   'positiveIncrease': 90587,
#   'totalTestResultsIncrease': 1389909,
#   'hash': '2dc18d76d816023d6da2661d236470d3d94f77d4'},
#  {'date': 20201030,
#   'states': 56,
#   'positive': 8958108,
#   'negative': 119045119,
#   'pending': 11120,
#   'hospitalizedCurrently': 46738,
#   'hospitalizedCumulative': 473597,
#   'inIcuCurrently': 9437,
#   'inIcuCumulative': 24230,
#   'onVentilatorCurrently': 2477,
#   'onVentilatorCumulative': 2776,
#   'recovered': 3576201,
#   'dateChecked': '2020-10-30T24:00:00Z',
#   'death': 221379,
#   'hospitalized': 473597,
#   'totalTestResults': 144798216,
#   'lastModified': '2020-10-30T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 952,
#   'hospitalizedIncrease': 2424,
#   'negativeIncrease': 975467,
#   'positiveIncrease': 97233,
#   'totalTestResultsIncrease': 1360460,
#   'hash': '59f33b0cef698d31e3707ce81b8ae6056d53c6de'},
#  {'date': 20201029,
#   'states': 56,
#   'positive': 8860875,
#   'negative': 118069652,
#   'pending': 10481,
#   'hospitalizedCurrently': 46126,
#   'hospitalizedCumulative': 471173,
#   'inIcuCurrently': 9208,
#   'inIcuCumulative': 24082,
#   'onVentilatorCurrently': 2403,
#   'onVentilatorCumulative': 2760,
#   'recovered': 3552166,
#   'dateChecked': '2020-10-29T24:00:00Z',
#   'death': 220427,
#   'hospitalized': 471173,
#   'totalTestResults': 143437756,
#   'lastModified': '2020-10-29T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1030,
#   'hospitalizedIncrease': 2324,
#   'negativeIncrease': 1009464,
#   'positiveIncrease': 88728,
#   'totalTestResultsIncrease': 1332268,
#   'hash': 'c45780c4ef20cbea86196c4effbc40f35fb92a47'},
#  {'date': 20201028,
#   'states': 56,
#   'positive': 8772147,
#   'negative': 117060188,
#   'pending': 9600,
#   'hospitalizedCurrently': 45124,
#   'hospitalizedCumulative': 468849,
#   'inIcuCurrently': 9034,
#   'inIcuCumulative': 23883,
#   'onVentilatorCurrently': 2347,
#   'onVentilatorCumulative': 2744,
#   'recovered': 3515953,
#   'dateChecked': '2020-10-28T24:00:00Z',
#   'death': 219397,
#   'hospitalized': 468849,
#   'totalTestResults': 142105488,
#   'lastModified': '2020-10-28T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1044,
#   'hospitalizedIncrease': 2471,
#   'negativeIncrease': 803139,
#   'positiveIncrease': 78748,
#   'totalTestResultsIncrease': 1092079,
#   'hash': 'b42b410a304f58ab98b94d9924d0f9f86fd04b9e'},
#  {'date': 20201027,
#   'states': 56,
#   'positive': 8693399,
#   'negative': 116257049,
#   'pending': 8129,
#   'hospitalizedCurrently': 44287,
#   'hospitalizedCumulative': 466378,
#   'inIcuCurrently': 8909,
#   'inIcuCumulative': 23701,
#   'onVentilatorCurrently': 2287,
#   'onVentilatorCumulative': 2719,
#   'recovered': 3485474,
#   'dateChecked': '2020-10-27T24:00:00Z',
#   'death': 218353,
#   'hospitalized': 466378,
#   'totalTestResults': 141013409,
#   'lastModified': '2020-10-27T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 920,
#   'hospitalizedIncrease': 2345,
#   'negativeIncrease': 806695,
#   'positiveIncrease': 72082,
#   'totalTestResultsIncrease': 1066081,
#   'hash': 'b9a10145e633be60deca03b9707f3839f17151f1'},
#  {'date': 20201026,
#   'states': 56,
#   'positive': 8621317,
#   'negative': 115450354,
#   'pending': 11083,
#   'hospitalizedCurrently': 42924,
#   'hospitalizedCumulative': 464033,
#   'inIcuCurrently': 8842,
#   'inIcuCumulative': 23542,
#   'onVentilatorCurrently': 2301,
#   'onVentilatorCumulative': 2703,
#   'recovered': 3458204,
#   'dateChecked': '2020-10-26T24:00:00Z',
#   'death': 217433,
#   'hospitalized': 464033,
#   'totalTestResults': 139947328,
#   'lastModified': '2020-10-26T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 402,
#   'hospitalizedIncrease': 1859,
#   'negativeIncrease': 983869,
#   'positiveIncrease': 62526,
#   'totalTestResultsIncrease': 1205446,
#   'hash': 'f31de8edbd2e2f18118317e0254b86ec33961118'},
#  {'date': 20201025,
#   'states': 56,
#   'positive': 8558791,
#   'negative': 114466485,
#   'pending': 11093,
#   'hospitalizedCurrently': 41786,
#   'hospitalizedCumulative': 462174,
#   'inIcuCurrently': 8489,
#   'inIcuCumulative': 23420,
#   'onVentilatorCurrently': 2176,
#   'onVentilatorCumulative': 2693,
#   'recovered': 3420713,
#   'dateChecked': '2020-10-25T24:00:00Z',
#   'death': 217031,
#   'hospitalized': 462174,
#   'totalTestResults': 138741882,
#   'lastModified': '2020-10-25T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 374,
#   'hospitalizedIncrease': 1106,
#   'negativeIncrease': 900669,
#   'positiveIncrease': 64893,
#   'totalTestResultsIncrease': 1187853,
#   'hash': '8ec6f7f799b1b41029e8a7dc1627b33fe9bb2468'},
#  {'date': 20201024,
#   'states': 56,
#   'positive': 8493898,
#   'negative': 113565816,
#   'pending': 11087,
#   'hospitalizedCurrently': 41989,
#   'hospitalizedCumulative': 461068,
#   'inIcuCurrently': 8561,
#   'inIcuCumulative': 23356,
#   'onVentilatorCurrently': 2230,
#   'onVentilatorCumulative': 2691,
#   'recovered': 3404503,
#   'dateChecked': '2020-10-24T24:00:00Z',
#   'death': 216657,
#   'hospitalized': 461068,
#   'totalTestResults': 137554029,
#   'lastModified': '2020-10-24T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 882,
#   'hospitalizedIncrease': 1751,
#   'negativeIncrease': 961479,
#   'positiveIncrease': 83286,
#   'totalTestResultsIncrease': 1322647,
#   'hash': '23ae19adc4f63924c346f19a3a8d5243afb4729f'},
#  {'date': 20201023,
#   'states': 56,
#   'positive': 8410612,
#   'negative': 112604337,
#   'pending': 11853,
#   'hospitalizedCurrently': 41501,
#   'hospitalizedCumulative': 459317,
#   'inIcuCurrently': 8237,
#   'inIcuCumulative': 23221,
#   'onVentilatorCurrently': 2180,
#   'onVentilatorCumulative': 2679,
#   'recovered': 3373284,
#   'dateChecked': '2020-10-23T24:00:00Z',
#   'death': 215775,
#   'hospitalized': 459317,
#   'totalTestResults': 136231382,
#   'lastModified': '2020-10-23T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 923,
#   'hospitalizedIncrease': 14992,
#   'negativeIncrease': 1042693,
#   'positiveIncrease': 82332,
#   'totalTestResultsIncrease': 1381536,
#   'hash': '434cc717c805252f1b16acae8ede8e4ba6846a3d'},
#  {'date': 20201022,
#   'states': 56,
#   'positive': 8328280,
#   'negative': 111561644,
#   'pending': 12222,
#   'hospitalizedCurrently': 41036,
#   'hospitalizedCumulative': 444325,
#   'inIcuCurrently': 8086,
#   'inIcuCumulative': 23018,
#   'onVentilatorCurrently': 2147,
#   'onVentilatorCumulative': 2641,
#   'recovered': 3350982,
#   'dateChecked': '2020-10-22T24:00:00Z',
#   'death': 214852,
#   'hospitalized': 444325,
#   'totalTestResults': 134849846,
#   'lastModified': '2020-10-22T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1136,
#   'hospitalizedIncrease': 2627,
#   'negativeIncrease': 917903,
#   'positiveIncrease': 72842,
#   'totalTestResultsIncrease': 1225535,
#   'hash': '5e65db0add04c86f5021b479d4cacd8adac6a1f0'},
#  {'date': 20201021,
#   'states': 56,
#   'positive': 8255438,
#   'negative': 110643741,
#   'pending': 10241,
#   'hospitalizedCurrently': 40284,
#   'hospitalizedCumulative': 441698,
#   'inIcuCurrently': 8182,
#   'inIcuCumulative': 22855,
#   'onVentilatorCurrently': 2090,
#   'onVentilatorCumulative': 2622,
#   'recovered': 3321258,
#   'dateChecked': '2020-10-21T24:00:00Z',
#   'death': 213716,
#   'hospitalized': 441698,
#   'totalTestResults': 133624311,
#   'lastModified': '2020-10-21T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1022,
#   'hospitalizedIncrease': 2205,
#   'negativeIncrease': 690765,
#   'positiveIncrease': 60953,
#   'totalTestResultsIncrease': 940885,
#   'hash': '1f07e5746d16f48edc5c1f1b1862ed9a222e13a1'},
#  {'date': 20201020,
#   'states': 56,
#   'positive': 8194485,
#   'negative': 109952976,
#   'pending': 8014,
#   'hospitalizedCurrently': 39303,
#   'hospitalizedCumulative': 439493,
#   'inIcuCurrently': 8131,
#   'inIcuCumulative': 22662,
#   'onVentilatorCurrently': 2045,
#   'onVentilatorCumulative': 2593,
#   'recovered': 3293315,
#   'dateChecked': '2020-10-20T24:00:00Z',
#   'death': 212694,
#   'hospitalized': 439493,
#   'totalTestResults': 132683426,
#   'lastModified': '2020-10-20T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 838,
#   'hospitalizedIncrease': 2231,
#   'negativeIncrease': 756336,
#   'positiveIncrease': 60547,
#   'totalTestResultsIncrease': 947980,
#   'hash': '795ac5692e193468101426e324293c3c393055eb'},
#  {'date': 20201019,
#   'states': 56,
#   'positive': 8133938,
#   'negative': 109196640,
#   'pending': 12138,
#   'hospitalizedCurrently': 37858,
#   'hospitalizedCumulative': 437262,
#   'inIcuCurrently': 7997,
#   'inIcuCumulative': 22475,
#   'onVentilatorCurrently': 1800,
#   'onVentilatorCumulative': 2577,
#   'recovered': 3270429,
#   'dateChecked': '2020-10-19T24:00:00Z',
#   'death': 211856,
#   'hospitalized': 437262,
#   'totalTestResults': 131735446,
#   'lastModified': '2020-10-19T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 461,
#   'hospitalizedIncrease': 1707,
#   'negativeIncrease': 1022378,
#   'positiveIncrease': 57110,
#   'totalTestResultsIncrease': 1126980,
#   'hash': '95c0b5c581d6f521c8a219d9d7ccbdfa3e872bd4'},
#  {'date': 20201018,
#   'states': 56,
#   'positive': 8076828,
#   'negative': 108174262,
#   'pending': 12059,
#   'hospitalizedCurrently': 36452,
#   'hospitalizedCumulative': 435555,
#   'inIcuCurrently': 7292,
#   'inIcuCumulative': 22391,
#   'onVentilatorCurrently': 1762,
#   'onVentilatorCumulative': 2557,
#   'recovered': 3231947,
#   'dateChecked': '2020-10-18T24:00:00Z',
#   'death': 211395,
#   'hospitalized': 435555,
#   'totalTestResults': 130608466,
#   'lastModified': '2020-10-18T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 397,
#   'hospitalizedIncrease': 800,
#   'negativeIncrease': 767502,
#   'positiveIncrease': 48284,
#   'totalTestResultsIncrease': 1052885,
#   'hash': 'f27c0f5eeb34725f127bf9dca01b267bc7a09e5d'},
#  {'date': 20201017,
#   'states': 56,
#   'positive': 8028544,
#   'negative': 107406760,
#   'pending': 12109,
#   'hospitalizedCurrently': 37358,
#   'hospitalizedCumulative': 434755,
#   'inIcuCurrently': 7384,
#   'inIcuCumulative': 22320,
#   'onVentilatorCurrently': 1791,
#   'onVentilatorCumulative': 2553,
#   'recovered': 3218561,
#   'dateChecked': '2020-10-17T24:00:00Z',
#   'death': 210998,
#   'hospitalized': 434755,
#   'totalTestResults': 129555581,
#   'lastModified': '2020-10-17T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 762,
#   'hospitalizedIncrease': 1553,
#   'negativeIncrease': 965191,
#   'positiveIncrease': 57330,
#   'totalTestResultsIncrease': 1298159,
#   'hash': '1bd2d293f4f989491380c7252ead3a9d8068fb95'},
#  {'date': 20201016,
#   'states': 56,
#   'positive': 7971214,
#   'negative': 106441569,
#   'pending': 13091,
#   'hospitalizedCurrently': 37368,
#   'hospitalizedCumulative': 433202,
#   'inIcuCurrently': 7251,
#   'inIcuCumulative': 22202,
#   'onVentilatorCurrently': 1739,
#   'onVentilatorCumulative': 2547,
#   'recovered': 3195422,
#   'dateChecked': '2020-10-16T24:00:00Z',
#   'death': 210236,
#   'hospitalized': 433202,
#   'totalTestResults': 128257422,
#   'lastModified': '2020-10-16T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 891,
#   'hospitalizedIncrease': 1861,
#   'negativeIncrease': 970413,
#   'positiveIncrease': 68248,
#   'totalTestResultsIncrease': 1228630,
#   'hash': '1c76e9e894ed50005a5ac37269e9d1a140c3748c'},
#  {'date': 20201015,
#   'states': 56,
#   'positive': 7902966,
#   'negative': 105471156,
#   'pending': 13001,
#   'hospitalizedCurrently': 37328,
#   'hospitalizedCumulative': 431341,
#   'inIcuCurrently': 7220,
#   'inIcuCumulative': 22051,
#   'onVentilatorCurrently': 1769,
#   'onVentilatorCumulative': 2531,
#   'recovered': 3175500,
#   'dateChecked': '2020-10-15T24:00:00Z',
#   'death': 209345,
#   'hospitalized': 431341,
#   'totalTestResults': 127028792,
#   'lastModified': '2020-10-15T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 937,
#   'hospitalizedIncrease': 2009,
#   'negativeIncrease': 851332,
#   'positiveIncrease': 63392,
#   'totalTestResultsIncrease': 1111181,
#   'hash': 'af77f595031fe370f206ccadcc5b2f2182c8f951'},
#  {'date': 20201014,
#   'states': 56,
#   'positive': 7839574,
#   'negative': 104619824,
#   'pending': 11100,
#   'hospitalizedCurrently': 37088,
#   'hospitalizedCumulative': 429332,
#   'inIcuCurrently': 7156,
#   'inIcuCumulative': 21889,
#   'onVentilatorCurrently': 1776,
#   'onVentilatorCumulative': 2516,
#   'recovered': 3153746,
#   'dateChecked': '2020-10-14T24:00:00Z',
#   'death': 208408,
#   'hospitalized': 429332,
#   'totalTestResults': 125917611,
#   'lastModified': '2020-10-14T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 816,
#   'hospitalizedIncrease': 2523,
#   'negativeIncrease': 621203,
#   'positiveIncrease': 56117,
#   'totalTestResultsIncrease': 1037705,
#   'hash': '8a05199d93438dff43be3ce57e21a991c3393732'},
#  {'date': 20201013,
#   'states': 56,
#   'positive': 7783457,
#   'negative': 103998621,
#   'pending': 8008,
#   'hospitalizedCurrently': 36064,
#   'hospitalizedCumulative': 426809,
#   'inIcuCurrently': 7020,
#   'inIcuCumulative': 21735,
#   'onVentilatorCurrently': 1755,
#   'onVentilatorCumulative': 2485,
#   'recovered': 3122531,
#   'dateChecked': '2020-10-13T24:00:00Z',
#   'death': 207592,
#   'hospitalized': 426809,
#   'totalTestResults': 124879906,
#   'lastModified': '2020-10-13T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 700,
#   'hospitalizedIncrease': 2115,
#   'negativeIncrease': 859108,
#   'positiveIncrease': 48593,
#   'totalTestResultsIncrease': 1049858,
#   'hash': '9d0a83ed107cf915f287cf59112c666bac36b73d'},
#  {'date': 20201012,
#   'states': 56,
#   'positive': 7734864,
#   'negative': 103139513,
#   'pending': 11329,
#   'hospitalizedCurrently': 35066,
#   'hospitalizedCumulative': 424694,
#   'inIcuCurrently': 6807,
#   'inIcuCumulative': 21625,
#   'onVentilatorCurrently': 1666,
#   'onVentilatorCumulative': 2464,
#   'recovered': 3104644,
#   'dateChecked': '2020-10-12T24:00:00Z',
#   'death': 206892,
#   'hospitalized': 424694,
#   'totalTestResults': 123830048,
#   'lastModified': '2020-10-12T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 287,
#   'hospitalizedIncrease': 1223,
#   'negativeIncrease': 883003,
#   'positiveIncrease': 42643,
#   'totalTestResultsIncrease': 1053929,
#   'hash': 'f9a9715b132ac81a8c268bb7a2e1c3629543c46f'},
#  {'date': 20201011,
#   'states': 56,
#   'positive': 7692221,
#   'negative': 102256510,
#   'pending': 11261,
#   'hospitalizedCurrently': 34498,
#   'hospitalizedCumulative': 423471,
#   'inIcuCurrently': 6679,
#   'inIcuCumulative': 21553,
#   'onVentilatorCurrently': 1646,
#   'onVentilatorCumulative': 2454,
#   'recovered': 3072920,
#   'dateChecked': '2020-10-11T24:00:00Z',
#   'death': 206605,
#   'hospitalized': 423471,
#   'totalTestResults': 122776119,
#   'lastModified': '2020-10-11T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 465,
#   'hospitalizedIncrease': 989,
#   'negativeIncrease': 802087,
#   'positiveIncrease': 46269,
#   'totalTestResultsIncrease': 1077671,
#   'hash': 'a5d923d0f07161121b85e8a868380d1551d99b9a'},
#  {'date': 20201010,
#   'states': 56,
#   'positive': 7645952,
#   'negative': 101454423,
#   'pending': 11223,
#   'hospitalizedCurrently': 34600,
#   'hospitalizedCumulative': 422482,
#   'inIcuCurrently': 6683,
#   'inIcuCumulative': 21512,
#   'onVentilatorCurrently': 1667,
#   'onVentilatorCumulative': 2451,
#   'recovered': 3061045,
#   'dateChecked': '2020-10-10T24:00:00Z',
#   'death': 206140,
#   'hospitalized': 422482,
#   'totalTestResults': 121698448,
#   'lastModified': '2020-10-10T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 666,
#   'hospitalizedIncrease': 1509,
#   'negativeIncrease': 961626,
#   'positiveIncrease': 57415,
#   'totalTestResultsIncrease': 1251177,
#   'hash': 'c194dfcbaa736cc37fe7dc219ad620f208607afc'},
#  {'date': 20201009,
#   'states': 56,
#   'positive': 7588537,
#   'negative': 100492797,
#   'pending': 13078,
#   'hospitalizedCurrently': 34877,
#   'hospitalizedCumulative': 420973,
#   'inIcuCurrently': 6713,
#   'inIcuCumulative': 21389,
#   'onVentilatorCurrently': 1655,
#   'onVentilatorCumulative': 2437,
#   'recovered': 3037145,
#   'dateChecked': '2020-10-09T24:00:00Z',
#   'death': 205474,
#   'hospitalized': 420973,
#   'totalTestResults': 120447271,
#   'lastModified': '2020-10-09T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 887,
#   'hospitalizedIncrease': 1761,
#   'negativeIncrease': 948164,
#   'positiveIncrease': 56802,
#   'totalTestResultsIncrease': 1201662,
#   'hash': 'b65da82af66b4dfcb77079c50100272584aee35a'},
#  {'date': 20201008,
#   'states': 56,
#   'positive': 7531735,
#   'negative': 99544633,
#   'pending': 13087,
#   'hospitalizedCurrently': 34319,
#   'hospitalizedCumulative': 419212,
#   'inIcuCurrently': 6621,
#   'inIcuCumulative': 21217,
#   'onVentilatorCurrently': 1638,
#   'onVentilatorCumulative': 2427,
#   'recovered': 3019299,
#   'dateChecked': '2020-10-08T24:00:00Z',
#   'death': 204587,
#   'hospitalized': 419212,
#   'totalTestResults': 119245609,
#   'lastModified': '2020-10-08T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 987,
#   'hospitalizedIncrease': 2102,
#   'negativeIncrease': 884627,
#   'positiveIncrease': 55208,
#   'totalTestResultsIncrease': 1154634,
#   'hash': '13671359fa41fde61fefdb36e761878f159b241e'},
#  {'date': 20201007,
#   'states': 56,
#   'positive': 7476527,
#   'negative': 98660006,
#   'pending': 12269,
#   'hospitalizedCurrently': 33482,
#   'hospitalizedCumulative': 417110,
#   'inIcuCurrently': 6507,
#   'inIcuCumulative': 21112,
#   'onVentilatorCurrently': 1646,
#   'onVentilatorCumulative': 2410,
#   'recovered': 2997942,
#   'dateChecked': '2020-10-07T24:00:00Z',
#   'death': 203600,
#   'hospitalized': 417110,
#   'totalTestResults': 118090975,
#   'lastModified': '2020-10-07T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 910,
#   'hospitalizedIncrease': 2265,
#   'negativeIncrease': 731556,
#   'positiveIncrease': 50590,
#   'totalTestResultsIncrease': 974437,
#   'hash': '9417c6d0b4e9bf6cfe29392d6b04b0881b707ace'},
#  {'date': 20201006,
#   'states': 56,
#   'positive': 7425937,
#   'negative': 97928450,
#   'pending': 8680,
#   'hospitalizedCurrently': 32626,
#   'hospitalizedCumulative': 414845,
#   'inIcuCurrently': 6438,
#   'inIcuCumulative': 20973,
#   'onVentilatorCurrently': 1609,
#   'onVentilatorCumulative': 2388,
#   'recovered': 2950348,
#   'dateChecked': '2020-10-06T24:00:00Z',
#   'death': 202690,
#   'hospitalized': 414845,
#   'totalTestResults': 117116538,
#   'lastModified': '2020-10-06T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 632,
#   'hospitalizedIncrease': -605,
#   'negativeIncrease': 716057,
#   'positiveIncrease': 38917,
#   'totalTestResultsIncrease': 908061,
#   'hash': 'd2dbc3e5c47989e83d14b3c9034475f026b364ce'},
#  {'date': 20201005,
#   'states': 56,
#   'positive': 7387020,
#   'negative': 97212393,
#   'pending': 11544,
#   'hospitalizedCurrently': 31327,
#   'hospitalizedCumulative': 415450,
#   'inIcuCurrently': 6209,
#   'inIcuCumulative': 20812,
#   'onVentilatorCurrently': 1515,
#   'onVentilatorCumulative': 2370,
#   'recovered': 2933035,
#   'dateChecked': '2020-10-05T24:00:00Z',
#   'death': 202058,
#   'hospitalized': 415450,
#   'totalTestResults': 116208477,
#   'lastModified': '2020-10-05T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 341,
#   'hospitalizedIncrease': 1541,
#   'negativeIncrease': 844249,
#   'positiveIncrease': 37756,
#   'totalTestResultsIncrease': 988270,
#   'hash': 'b02796a6aa52756515e25b64841ab3735e03626a'},
#  {'date': 20201004,
#   'states': 56,
#   'positive': 7349264,
#   'negative': 96368144,
#   'pending': 11471,
#   'hospitalizedCurrently': 29945,
#   'hospitalizedCumulative': 413909,
#   'inIcuCurrently': 5974,
#   'inIcuCumulative': 20729,
#   'onVentilatorCurrently': 1485,
#   'onVentilatorCumulative': 2362,
#   'recovered': 2909644,
#   'dateChecked': '2020-10-04T24:00:00Z',
#   'death': 201717,
#   'hospitalized': 413909,
#   'totalTestResults': 115220207,
#   'lastModified': '2020-10-04T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 362,
#   'hospitalizedIncrease': 642,
#   'negativeIncrease': 823151,
#   'positiveIncrease': 37988,
#   'totalTestResultsIncrease': 1027485,
#   'hash': '27a95b1a09c30256f4b6009151234989251a898c'},
#  {'date': 20201003,
#   'states': 56,
#   'positive': 7311276,
#   'negative': 95544993,
#   'pending': 11464,
#   'hospitalizedCurrently': 30111,
#   'hospitalizedCumulative': 413267,
#   'inIcuCurrently': 5996,
#   'inIcuCumulative': 20686,
#   'onVentilatorCurrently': 1501,
#   'onVentilatorCumulative': 2358,
#   'recovered': 2895307,
#   'dateChecked': '2020-10-03T24:00:00Z',
#   'death': 201355,
#   'hospitalized': 413267,
#   'totalTestResults': 114192722,
#   'lastModified': '2020-10-03T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 733,
#   'hospitalizedIncrease': 1106,
#   'negativeIncrease': 844987,
#   'positiveIncrease': 50935,
#   'totalTestResultsIncrease': 1097641,
#   'hash': '155c686a8ac03b2e17dcf71b233380a44a158f3f'},
#  {'date': 20201002,
#   'states': 56,
#   'positive': 7260341,
#   'negative': 94700006,
#   'pending': 10813,
#   'hospitalizedCurrently': 30769,
#   'hospitalizedCumulative': 412161,
#   'inIcuCurrently': 6106,
#   'inIcuCumulative': 20612,
#   'onVentilatorCurrently': 1533,
#   'onVentilatorCumulative': 2348,
#   'recovered': 2871287,
#   'dateChecked': '2020-10-02T24:00:00Z',
#   'death': 200622,
#   'hospitalized': 412161,
#   'totalTestResults': 113095081,
#   'lastModified': '2020-10-02T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 839,
#   'hospitalizedIncrease': 1401,
#   'negativeIncrease': 975206,
#   'positiveIncrease': 49257,
#   'totalTestResultsIncrease': 1240952,
#   'hash': '788404cd77c6837fdbd92d4facee71daf8bdd0a7'},
#  {'date': 20201001,
#   'states': 56,
#   'positive': 7211084,
#   'negative': 93724800,
#   'pending': 13003,
#   'hospitalizedCurrently': 30809,
#   'hospitalizedCumulative': 410760,
#   'inIcuCurrently': 6173,
#   'inIcuCumulative': 20492,
#   'onVentilatorCurrently': 1547,
#   'onVentilatorCumulative': 2334,
#   'recovered': 2858704,
#   'dateChecked': '2020-10-01T24:00:00Z',
#   'death': 199783,
#   'hospitalized': 410760,
#   'totalTestResults': 111854129,
#   'lastModified': '2020-10-01T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 848,
#   'hospitalizedIncrease': 1766,
#   'negativeIncrease': 763591,
#   'positiveIncrease': 45605,
#   'totalTestResultsIncrease': 1003311,
#   'hash': 'd79b68d8936e1c4565e998b94f12675ae6208acf'},
#  {'date': 20200930,
#   'states': 56,
#   'positive': 7165479,
#   'negative': 92961209,
#   'pending': 9431,
#   'hospitalizedCurrently': 30912,
#   'hospitalizedCumulative': 408994,
#   'inIcuCurrently': 6145,
#   'inIcuCumulative': 20390,
#   'onVentilatorCurrently': 1507,
#   'onVentilatorCumulative': 2319,
#   'recovered': 2838664,
#   'dateChecked': '2020-09-30T24:00:00Z',
#   'death': 198935,
#   'hospitalized': 408994,
#   'totalTestResults': 110850818,
#   'lastModified': '2020-09-30T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1062,
#   'hospitalizedIncrease': 1582,
#   'negativeIncrease': 676355,
#   'positiveIncrease': 44347,
#   'totalTestResultsIncrease': 906365,
#   'hash': '72f79ae062a611aca7c0a7d9a93637d7bc36d708'},
#  {'date': 20200929,
#   'states': 56,
#   'positive': 7121132,
#   'negative': 92284854,
#   'pending': 7695,
#   'hospitalizedCurrently': 30499,
#   'hospitalizedCumulative': 407412,
#   'inIcuCurrently': 6106,
#   'inIcuCumulative': 20247,
#   'onVentilatorCurrently': 1495,
#   'onVentilatorCumulative': 2298,
#   'recovered': 2811386,
#   'dateChecked': '2020-09-29T24:00:00Z',
#   'death': 197873,
#   'hospitalized': 407412,
#   'totalTestResults': 109944453,
#   'lastModified': '2020-09-29T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 740,
#   'hospitalizedIncrease': 1750,
#   'negativeIncrease': 711277,
#   'positiveIncrease': 36441,
#   'totalTestResultsIncrease': 916666,
#   'hash': '8d46e355ddab7483899ff33533b658483326ba28'},
#  {'date': 20200928,
#   'states': 56,
#   'positive': 7084691,
#   'negative': 91573577,
#   'pending': 11112,
#   'hospitalizedCurrently': 29601,
#   'hospitalizedCumulative': 405662,
#   'inIcuCurrently': 5981,
#   'inIcuCumulative': 20121,
#   'onVentilatorCurrently': 1518,
#   'onVentilatorCumulative': 2285,
#   'recovered': 2792677,
#   'dateChecked': '2020-09-28T24:00:00Z',
#   'death': 197133,
#   'hospitalized': 405662,
#   'totalTestResults': 109027787,
#   'lastModified': '2020-09-28T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 265,
#   'hospitalizedIncrease': 1258,
#   'negativeIncrease': 912524,
#   'positiveIncrease': 35883,
#   'totalTestResultsIncrease': 1158486,
#   'hash': 'aa7bcf3dab686f6acd898944c307c5da5895ed03'},
#  {'date': 20200927,
#   'states': 56,
#   'positive': 7048808,
#   'negative': 90661053,
#   'pending': 11136,
#   'hospitalizedCurrently': 29443,
#   'hospitalizedCumulative': 404404,
#   'inIcuCurrently': 6080,
#   'inIcuCumulative': 20050,
#   'onVentilatorCurrently': 1511,
#   'onVentilatorCumulative': 2277,
#   'recovered': 2764336,
#   'dateChecked': '2020-09-27T24:00:00Z',
#   'death': 196868,
#   'hospitalized': 404404,
#   'totalTestResults': 107869301,
#   'lastModified': '2020-09-27T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 302,
#   'hospitalizedIncrease': 719,
#   'negativeIncrease': 669506,
#   'positiveIncrease': 34987,
#   'totalTestResultsIncrease': 904228,
#   'hash': 'd567b7fbbf02316dabac82a45f6870ed97299a7f'},
#  {'date': 20200926,
#   'states': 56,
#   'positive': 7013821,
#   'negative': 89991547,
#   'pending': 11183,
#   'hospitalizedCurrently': 29551,
#   'hospitalizedCumulative': 403685,
#   'inIcuCurrently': 6057,
#   'inIcuCumulative': 20002,
#   'onVentilatorCurrently': 1509,
#   'onVentilatorCumulative': 2272,
#   'recovered': 2748595,
#   'dateChecked': '2020-09-26T24:00:00Z',
#   'death': 196566,
#   'hospitalized': 403685,
#   'totalTestResults': 106965073,
#   'lastModified': '2020-09-26T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 863,
#   'hospitalizedIncrease': 1169,
#   'negativeIncrease': 886741,
#   'positiveIncrease': 47403,
#   'totalTestResultsIncrease': 1122806,
#   'hash': '894ea481ea11c63964596db9b23fb05090812a1c'},
#  {'date': 20200925,
#   'states': 56,
#   'positive': 6966418,
#   'negative': 89104806,
#   'pending': 10905,
#   'hospitalizedCurrently': 29768,
#   'hospitalizedCumulative': 402516,
#   'inIcuCurrently': 6133,
#   'inIcuCumulative': 19919,
#   'onVentilatorCurrently': 1506,
#   'onVentilatorCumulative': 2264,
#   'recovered': 2725475,
#   'dateChecked': '2020-09-25T24:00:00Z',
#   'death': 195703,
#   'hospitalized': 402516,
#   'totalTestResults': 105842267,
#   'lastModified': '2020-09-25T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 844,
#   'hospitalizedIncrease': 1352,
#   'negativeIncrease': 876779,
#   'positiveIncrease': 55189,
#   'totalTestResultsIncrease': 1115236,
#   'hash': '765091eb15c334b430c61aaaca214c9065b8e0bd'},
#  {'date': 20200924,
#   'states': 56,
#   'positive': 6911229,
#   'negative': 88228027,
#   'pending': 12008,
#   'hospitalizedCurrently': 30036,
#   'hospitalizedCumulative': 401164,
#   'inIcuCurrently': 6168,
#   'inIcuCumulative': 19555,
#   'onVentilatorCurrently': 1560,
#   'onVentilatorCumulative': 2177,
#   'recovered': 2708310,
#   'dateChecked': '2020-09-24T24:00:00Z',
#   'death': 194859,
#   'hospitalized': 401164,
#   'totalTestResults': 104727031,
#   'lastModified': '2020-09-24T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 929,
#   'hospitalizedIncrease': 1571,
#   'negativeIncrease': 802979,
#   'positiveIncrease': 43346,
#   'totalTestResultsIncrease': 1040093,
#   'hash': '53ffbdca2e327e956eba5ef2ae95af492ee8ffaa'},
#  {'date': 20200923,
#   'states': 56,
#   'positive': 6867883,
#   'negative': 87425048,
#   'pending': 10535,
#   'hospitalizedCurrently': 29937,
#   'hospitalizedCumulative': 399593,
#   'inIcuCurrently': 6113,
#   'inIcuCumulative': 19452,
#   'onVentilatorCurrently': 1544,
#   'onVentilatorCumulative': 2154,
#   'recovered': 2670381,
#   'dateChecked': '2020-09-23T24:00:00Z',
#   'death': 193930,
#   'hospitalized': 399593,
#   'totalTestResults': 103686938,
#   'lastModified': '2020-09-23T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1147,
#   'hospitalizedIncrease': 1441,
#   'negativeIncrease': 804138,
#   'positiveIncrease': 38620,
#   'totalTestResultsIncrease': 1011089,
#   'hash': '4bc3dfe4d6d2507be6ae252350d5b0d2ca4a4eb9'},
#  {'date': 20200922,
#   'states': 56,
#   'positive': 6829263,
#   'negative': 86620910,
#   'pending': 7999,
#   'hospitalizedCurrently': 29448,
#   'hospitalizedCumulative': 398152,
#   'inIcuCurrently': 6111,
#   'inIcuCumulative': 19324,
#   'onVentilatorCurrently': 1562,
#   'onVentilatorCumulative': 2130,
#   'recovered': 2645001,
#   'dateChecked': '2020-09-22T24:00:00Z',
#   'death': 192783,
#   'hospitalized': 398152,
#   'totalTestResults': 102675849,
#   'lastModified': '2020-09-22T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 866,
#   'hospitalizedIncrease': 1478,
#   'negativeIncrease': 673794,
#   'positiveIncrease': 49475,
#   'totalTestResultsIncrease': 855109,
#   'hash': '2c9feb6606b77e557ab7b7fe85f649d185b0a720'},
#  {'date': 20200921,
#   'states': 56,
#   'positive': 6779788,
#   'negative': 85947116,
#   'pending': 13241,
#   'hospitalizedCurrently': 28762,
#   'hospitalizedCumulative': 396674,
#   'inIcuCurrently': 6071,
#   'inIcuCumulative': 19353,
#   'onVentilatorCurrently': 1572,
#   'onVentilatorCumulative': 2116,
#   'recovered': 2614069,
#   'dateChecked': '2020-09-21T24:00:00Z',
#   'death': 191917,
#   'hospitalized': 396674,
#   'totalTestResults': 101820740,
#   'lastModified': '2020-09-21T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 288,
#   'hospitalizedIncrease': 1160,
#   'negativeIncrease': 636803,
#   'positiveIncrease': 39139,
#   'totalTestResultsIncrease': 771045,
#   'hash': 'fca7b63e926bef65f84e17f132773427623bc50d'},
#  {'date': 20200920,
#   'states': 56,
#   'positive': 6740649,
#   'negative': 85310313,
#   'pending': 13192,
#   'hospitalizedCurrently': 28606,
#   'hospitalizedCumulative': 395514,
#   'inIcuCurrently': 6015,
#   'inIcuCumulative': 19281,
#   'onVentilatorCurrently': 1595,
#   'onVentilatorCumulative': 2112,
#   'recovered': 2587314,
#   'dateChecked': '2020-09-20T24:00:00Z',
#   'death': 191629,
#   'hospitalized': 395514,
#   'totalTestResults': 101049695,
#   'lastModified': '2020-09-20T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 323,
#   'hospitalizedIncrease': 507,
#   'negativeIncrease': 788663,
#   'positiveIncrease': 35503,
#   'totalTestResultsIncrease': 976833,
#   'hash': 'fa87f01e93ac028403bac6421545dc23d228a41a'},
#  {'date': 20200919,
#   'states': 56,
#   'positive': 6705146,
#   'negative': 84521650,
#   'pending': 13217,
#   'hospitalizedCurrently': 29038,
#   'hospitalizedCumulative': 395007,
#   'inIcuCurrently': 6070,
#   'inIcuCumulative': 19243,
#   'onVentilatorCurrently': 1577,
#   'onVentilatorCumulative': 2111,
#   'recovered': 2575561,
#   'dateChecked': '2020-09-19T24:00:00Z',
#   'death': 191306,
#   'hospitalized': 395007,
#   'totalTestResults': 100072862,
#   'lastModified': '2020-09-19T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 739,
#   'hospitalizedIncrease': 1065,
#   'negativeIncrease': 945717,
#   'positiveIncrease': 44905,
#   'totalTestResultsIncrease': 1175581,
#   'hash': 'a22f9807f635d35419722ce44dd185d151965804'},
#  {'date': 20200918,
#   'states': 56,
#   'positive': 6660241,
#   'negative': 83575933,
#   'pending': 11805,
#   'hospitalizedCurrently': 29521,
#   'hospitalizedCumulative': 393942,
#   'inIcuCurrently': 6175,
#   'inIcuCumulative': 19163,
#   'onVentilatorCurrently': 1608,
#   'onVentilatorCumulative': 2107,
#   'recovered': 2556013,
#   'dateChecked': '2020-09-18T24:00:00Z',
#   'death': 190567,
#   'hospitalized': 393942,
#   'totalTestResults': 98897281,
#   'lastModified': '2020-09-18T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 898,
#   'hospitalizedIncrease': 1431,
#   'negativeIncrease': 853088,
#   'positiveIncrease': 47251,
#   'totalTestResultsIncrease': 1093041,
#   'hash': '6bc393d6621f97a0656e3756e3c335e360ab1e2a'},
#  {'date': 20200917,
#   'states': 56,
#   'positive': 6612990,
#   'negative': 82722845,
#   'pending': 11768,
#   'hospitalizedCurrently': 29875,
#   'hospitalizedCumulative': 392511,
#   'inIcuCurrently': 6278,
#   'inIcuCumulative': 19057,
#   'onVentilatorCurrently': 1658,
#   'onVentilatorCumulative': 2092,
#   'recovered': 2538622,
#   'dateChecked': '2020-09-17T24:00:00Z',
#   'death': 189669,
#   'hospitalized': 392511,
#   'totalTestResults': 97804240,
#   'lastModified': '2020-09-17T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 871,
#   'hospitalizedIncrease': 1572,
#   'negativeIncrease': 737534,
#   'positiveIncrease': 43289,
#   'totalTestResultsIncrease': 969600,
#   'hash': 'd4807d87af5a01e07c52f616b7aaff756d823b8f'},
#  {'date': 20200916,
#   'states': 56,
#   'positive': 6569701,
#   'negative': 81985311,
#   'pending': 10587,
#   'hospitalizedCurrently': 30253,
#   'hospitalizedCumulative': 390939,
#   'inIcuCurrently': 6308,
#   'inIcuCumulative': 18961,
#   'onVentilatorCurrently': 1651,
#   'onVentilatorCumulative': 2090,
#   'recovered': 2523824,
#   'dateChecked': '2020-09-16T24:00:00Z',
#   'death': 188798,
#   'hospitalized': 390939,
#   'totalTestResults': 96834640,
#   'lastModified': '2020-09-16T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1184,
#   'hospitalizedIncrease': 1522,
#   'negativeIncrease': 628661,
#   'positiveIncrease': 40110,
#   'totalTestResultsIncrease': 827216,
#   'hash': '21cc1a2fa881b7eecd8b576d7de6a958d9f805a7'},
#  {'date': 20200915,
#   'states': 56,
#   'positive': 6529591,
#   'negative': 81356650,
#   'pending': 4966,
#   'hospitalizedCurrently': 30361,
#   'hospitalizedCumulative': 389417,
#   'inIcuCurrently': 6310,
#   'inIcuCumulative': 18847,
#   'onVentilatorCurrently': 1572,
#   'onVentilatorCumulative': 2071,
#   'recovered': 2493331,
#   'dateChecked': '2020-09-15T24:00:00Z',
#   'death': 187614,
#   'hospitalized': 389417,
#   'totalTestResults': 96007424,
#   'lastModified': '2020-09-15T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 1044,
#   'hospitalizedIncrease': 1506,
#   'negativeIncrease': 651693,
#   'positiveIncrease': 34904,
#   'totalTestResultsIncrease': 813300,
#   'hash': 'f1ecdee63d020ff26eb4b3f67415a0d9b1017717'},
#  {'date': 20200914,
#   'states': 56,
#   'positive': 6494687,
#   'negative': 80704957,
#   'pending': 10494,
#   'hospitalizedCurrently': 29907,
#   'hospitalizedCumulative': 387911,
#   'inIcuCurrently': 6238,
#   'inIcuCumulative': 18748,
#   'onVentilatorCurrently': 1507,
#   'onVentilatorCumulative': 2061,
#   'recovered': 2476089,
#   'dateChecked': '2020-09-14T24:00:00Z',
#   'death': 186570,
#   'hospitalized': 387911,
#   'totalTestResults': 95194124,
#   'lastModified': '2020-09-14T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 407,
#   'hospitalizedIncrease': 952,
# ...
#   'totalTestResultsIncrease': 4,
#   'hash': 'd448924f6e8d3821f6cac327d9adeb9ab80fafbd'},
#  {'date': 20200214,
#   'states': 4,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-14T24:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'totalTestResults': 22,
#   'lastModified': '2020-02-14T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': 'b15e417020f36211457b73074ba97fcd9ce18fcc'},
#  {'date': 20200213,
#   'states': 4,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-13T24:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'totalTestResults': 22,
#   'lastModified': '2020-02-13T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': 'e7f1d19566188f1e2db1641b34468e5203955a0c'},
#  {'date': 20200212,
#   'states': 4,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-12T24:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'totalTestResults': 21,
#   'lastModified': '2020-02-12T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': 'd629f94558bba2c702090373345ab1caa5d0e5e4'},
#  {'date': 20200211,
#   'states': 4,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-11T24:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'totalTestResults': 20,
#   'lastModified': '2020-02-11T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': '3603bce83b082d86cd9c5d8e20c2355e1cafce65'},
#  {'date': 20200210,
#   'states': 4,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-10T24:00:00Z',
#   'death': 0,
#   'hospitalized': None,
#   'totalTestResults': 19,
#   'lastModified': '2020-02-10T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': 'd66ae981cb25f82b7bdde2b5cdf0d738e3c908a2'},
#  {'date': 20200209,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-09T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 18,
#   'lastModified': '2020-02-09T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': 'a4c94f822733ee9e8ecdcc423675b7dffda0fdd6'},
#  {'date': 20200208,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-08T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 18,
#   'lastModified': '2020-02-08T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 2,
#   'hash': '70527afe918e19d08318d69f1c08166da805836c'},
#  {'date': 20200207,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-07T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 16,
#   'lastModified': '2020-02-07T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '1cc36d0e0b50a528f3648b2dc50a3588b5f97675'},
#  {'date': 20200206,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-06T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 16,
#   'lastModified': '2020-02-06T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': 'e2aa89ba20de38762574e78004d9af7ed3872f70'},
#  {'date': 20200205,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-05T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 15,
#   'lastModified': '2020-02-05T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '4f324d4cf66b8ba7b601b44a705dbeac03f83ac5'},
#  {'date': 20200204,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-04T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 15,
#   'lastModified': '2020-02-04T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 4,
#   'hash': '1ee2bd0c3dd00befe2204767abe8e06490571579'},
#  {'date': 20200203,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-03T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 11,
#   'lastModified': '2020-02-03T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 3,
#   'hash': '9aa6ad0825d09a247785242b8178ca4e34899be5'},
#  {'date': 20200202,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-02T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 8,
#   'lastModified': '2020-02-02T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': 'f2a379724608d8ac316ec4ce40be7cc7ae65ac99'},
#  {'date': 20200201,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-02-01T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 8,
#   'lastModified': '2020-02-01T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '2cba46fe76e0f2059360e6e72a7d8b30ff65a3a4'},
#  {'date': 20200131,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-31T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 8,
#   'lastModified': '2020-01-31T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 3,
#   'hash': '42a943021908c2b30ed4ff8a167cf85b67c74a64'},
#  {'date': 20200130,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-30T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 5,
#   'lastModified': '2020-01-30T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': 'fcc4f0bddc597038fdae38186a3c04abed3bcafb'},
#  {'date': 20200129,
#   'states': 3,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-29T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 5,
#   'lastModified': '2020-01-29T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 2,
#   'hash': 'b70b347abb1a57042bb79f346f701f4dadaaef97'},
#  {'date': 20200128,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-28T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 3,
#   'lastModified': '2020-01-28T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '0b29231acff528952fcbb6fa30daeef620d3f707'},
#  {'date': 20200127,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-27T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 3,
#   'lastModified': '2020-01-27T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': '6fd2348b0ace6226478a9bff8ba1bf1de2733360'},
#  {'date': 20200126,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-26T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 2,
#   'lastModified': '2020-01-26T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '69c67c81e64d10a5270497fc5336779c06fb812b'},
#  {'date': 20200125,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-25T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 2,
#   'lastModified': '2020-01-25T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '9ea5731f5b0a79617b994d6842eecfdbeb1dde35'},
#  {'date': 20200124,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-24T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 2,
#   'lastModified': '2020-01-24T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': '287531342bc8d5f2650b0cc12ebcca3807a64b7b'},
#  {'date': 20200123,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-23T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 2,
#   'lastModified': '2020-01-23T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 1,
#   'hash': 'e0563aac8e1bc7b8b8059c52831b97179ff6f981'},
#  {'date': 20200122,
#   'states': 2,
#   'positive': 0,
#   'negative': 0,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dateChecked': '2020-01-22T24:00:00Z',
#   'death': None,
#   'hospitalized': None,
#   'totalTestResults': 1,
#   'lastModified': '2020-01-22T24:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'negativeIncrease': 0,
#   'positiveIncrease': 0,
#   'totalTestResultsIncrease': 0,
#   'hash': 'e0caa1c66c4aa83baf227afe12261a1493fc0d7e'}]
